# %%
import osmnx as ox
import contextily as cx
import matplotlib.pyplot as plt
import cenpy
import geopandas
import geodatasets
# Out:
# /opt/anaconda3/envs/JeepneyRerouting/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Creating Bounding Box

# %%
# bounding box for Subangdaku Flyover (zoomed out)
# north, south, east, west
BOUNDING_BOX = (10.32911, 10.31629, 123.93381, 123.91896)

# %%
# bounding box for Subangdaku Flyover
# north, south, east, west
BOUNDING_BOX = (10.324546, 10.321295, 123.927353, 123.922310)

# %%
flyover_graph = ox.graph_from_bbox(bbox=BOUNDING_BOX)
# Out:
# /tmp/ipykernel_11700/3150808005.py:1: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   flyover_graph = ox.graph_from_bbox(bbox=BOUNDING_BOX)

# %%
flyover_graph

# %% [markdown]
# ### Plot Flyover

# %%
plot = ox.plot_graph(flyover_graph)

# %%
ox.plot_figure_ground(flyover_graph)
# Out:
# /opt/anaconda3/envs/JeepneyRerouting/lib/python3.8/site-packages/osmnx/plot.py:616: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   fig, ax = plot_graph(
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Overlaying Maps

# %%
cebu_nodes, cebu_streets = ox.graph_to_gdfs(flyover_graph)

# %%
cebu_streets.columns.values
# Out:
# array(['osmid', 'oneway', 'lanes', 'ref', 'name', 'highway', 'maxspeed',
#        'reversed', 'length', 'geometry', 'bridge', 'access', 'service'],
#       dtype=object)

# %%
cebu_streets.head()
# Out:
#                               osmid lanes  ref                  name  \
# u         v          key
# 446096986 5905589986 0     37981564     4    8    Lopez Jaena Street
#           579619487  0    304632203     4    8    Lopez Jaena Street
#           612942026  0    590032303   NaN  NaN                   NaN
# 490265719 579619214  0     45489270   NaN  NaN  Hernan Cortes Street
# 494121285 8366180946 0    900615506     1  NaN  Hernan Cortes Street
#
#                                highway maxspeed  oneway  reversed  length  \
# u         v          key
# 446096986 5905589986 0         primary       50   False     False  13.446
#           579619487  0         primary       50   False      True  33.294
#           612942026  0    primary_link       50    True     False  36.851
# 490265719 579619214  0       secondary       40   False      True   4.273
# 494121285 8366180946 0       secondary       40    True     False  25.150
#
#                                                                    geometry  \
# u         v          key
# 446096986 5905589986 0    LINESTRING (123.92474 10.32329, 123.92483 10.3...
#           579619487  0    LINESTRING (123.92474 10.32329, 123.92451 10.3...
#           612942026  0    LINESTRING (123.92474 10.32329, 123.92461 10.3...
# 490265719 579619214  0    LINESTRING (123.92335 10.32449, 123.92337 10.3...
# 494121285 8366180946 0    LINESTRING (123.92580 10.32135, 123.92565 10.3...
#
#                          bridge access service
# u         v          key
# 446096986 5905589986 0      NaN    NaN     NaN
#           579619487  0      NaN    NaN     NaN
#           612942026  0      NaN    NaN     NaN
# 490265719 579619214  0      NaN    NaN     NaN
# 494121285 8366180946 0      NaN    NaN     NaN

# %%
cebu_nodes.head()
# Out:
#                    y           x  street_count                    geometry
# osmid
# 446096986  10.323295  123.924740             4  POINT (123.92474 10.32329)
# 490265719  10.324494  123.923351             3  POINT (123.92335 10.32449)
# 494121285  10.321348  123.925804             3  POINT (123.92580 10.32135)
# 579619214  10.324460  123.923371             4  POINT (123.92337 10.32446)
# 579619329  10.322938  123.924638             3  POINT (123.92464 10.32294)

# %%
# read the coordinate system
cebu_streets.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
cebu_nodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# convert coordinate system to mercator
cebu_streets_mercator = cebu_streets.to_crs(epsg=3857)
cebu_nodes_mercator = cebu_streets.to_crs(epsg=3857)

# %%
f,ax = plt.subplots(1,1, figsize=(15,15))
cebu_streets_mercator.plot(linewidth=.25, ax=ax, color='k')
cebu_nodes_mercator.plot(ax=ax)
cx.add_basemap(ax=ax, url=cx.providers.CartoDB.Positron)

# %% [markdown]
# ## Overlaying Flood Hazard Map

# %%
# read flood hazard map
flood_hazard_5yr = geopandas.read_file('noah_data/5yr/5yr.zip')

# %%
# read flood hazard map
flood_hazard_5yr = geopandas.read_file('noah_data/5yr/Cebu_Flood_5year.shp')

# %%
flood_hazard_5yr.head()
# Out:
#    Var                                           geometry
# 0  1.0  MULTIPOLYGON (((123.83350 10.23442, 123.83349 ...
# 1  2.0  MULTIPOLYGON (((123.83442 10.23465, 123.83442 ...
# 2  3.0  MULTIPOLYGON (((123.83458 10.23493, 123.83460 ...

# %%
flood_hazard_5yr.plot(figsize=(10, 10))
# Out:
# <Axes: >

# %%
# get the type of projection
flood_hazard_5yr.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
flood_hazard_5yr_web_mercator = flood_hazard_5yr.to_crs(epsg=3857)
ax = flood_hazard_5yr_web_mercator.plot(figsize=(10, 10), alpha=0.5)
cx.add_basemap(ax, crs=flood_hazard_5yr_web_mercator.crs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 flood_hazard_5yr_web_mercator = flood_hazard_5yr.to_crs(epsg=3857)
#       2 ax = flood_hazard_5yr_web_mercator.plot(figsize=(10, 10), alpha=0.5)
# ----> 3 cx.add_basemap(ax, crs=flood_hazard_5yr_web_mercator.crs)
#
# File /opt/anaconda3/envs/JeepneyRerouting/lib/python3.8/site-packages/contextily/plotting.py:134, in add_basemap(ax, zoom, source, interpolation, attribution, attribution_size, reset_extent, crs, resampling, zoom_adjust, **extra_imshow_args)
#     130     left, right, bottom, top = _reproj_bb(
#     131         left, right, bottom, top, crs, "epsg:3857"
#     132     )
#     133 # Download image
# --> 134 image, extent = bounds2img(
#     135     left, bottom, right, top, zoom=zoom, source=source, ll=False, zoom_adjust=zoom_adjust
#     136 )
#     137 # Warping
#     138 if crs is not None:
#
# File /opt/anaconda3/envs/JeepneyRerouting/lib/python3.8/site-packages/contextily/tile.py:265, in bounds2img(w, s, e, n, zoom, source, ll, wait, max_retries, n_connections, use_cache, zoom_adjust)
#     262 arrays = Parallel(n_jobs=n_connections, prefer=preferred_backend)(
#     263     delayed(fetch_tile_fn)(tile_url, wait, max_retries) for tile_url in tile_urls)
#     264 # merge downloaded tiles
# --> 265 merged, extent = _merge_tiles(tiles, arrays)
#     266 # lon/lat extent --> Spheric Mercator
#     267 west, south, east, north = extent
#
# File /opt/anaconda3/envs/JeepneyRerouting/lib/python3.8/site-packages/contextily/tile.py:660, in _merge_tiles(tiles, arrays)
#     657 indices = tile_xys - tile_xys.min(axis=0)
#     659 # the shape of individual tile images
# --> 660 h, w, d = arrays[0].shape
#     662 # number of rows and columns in the merged tile
#     663 n_x, n_y = (indices + 1).max(axis=0)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ## Working With The Graph
