# %%
import geopandas
import contextily as cx

# %%
BOUNDING_BOX = (123.922310, 10.321295, 123.927353, 10.324546)

# %%
gdf = geopandas.read_file('graphs/geopackage/2024-09-21 02-26-20.045536 graph.gpkg', bbox=BOUNDING_BOX)

# %%
gdf.head()
# Out:
#         osmid          y           x  street_count highway ref  \
# 0   494121285  10.321348  123.925804             3
# 1  1104399332  10.321478  123.922665             3
# 2  5797678476  10.321493  123.925593             3
# 3   490265719  10.324494  123.923351             3
# 4   579619214  10.324460  123.923371             4
#
#                      geometry
# 0  POINT (123.92580 10.32135)
# 1  POINT (123.92267 10.32148)
# 2  POINT (123.92559 10.32149)
# 3  POINT (123.92335 10.32449)
# 4  POINT (123.92337 10.32446)

# %%
# plot the graph
gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
# Out:
# <Axes: >

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_webmercator = gdf.to_crs(epsg=3857)

# %%
ax = gdf_webmercator.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
cx.add_basemap(ax)
