# %%
import pandas as pd

# %%
df = pd.read_csv('flood_data_from_tweets/sensitive.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17394 entries, 0 to 17393
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               17394 non-null  int64
#  1   location ID            17394 non-null  object
#  2   location URL           17394 non-null  object
#  3   Location name          17394 non-null  object
#  4   Location type          17394 non-null  object
#  5   ISO 3116 country code  17394 non-null  object
#  6   Start time             17394 non-null  object
#  7   End time               17394 non-null  object
#  8   Time of detection      17394 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['event_id', 'location ID', 'location URL', 'Location name',
#        'Location type', 'ISO 3116 country code', 'Start time', 'End time',
#        'Time of detection'],
#       dtype='object')

# %%
df.head()
# Out:
#    event_id location ID                     location URL Location name  \
# 0         1   g-5332921  http://www.geonames.org/5332921    California
# 1         2   g-5417618  http://www.geonames.org/5417618      Colorado
# 2         3   g-5481136  http://www.geonames.org/5481136    New Mexico
# 3         5   g-4043988  http://www.geonames.org/4043988          Guam
# 4         6   g-5549030  http://www.geonames.org/5549030          Utah
#
#   Location type ISO 3116 country code           Start time  \
# 0          adm1                   USA  2014-07-30T00:00:14
# 1          adm1                   USA  2014-07-30T00:03:36
# 2          adm1                   USA  2014-07-30T00:16:53
# 3       country                   GUM  2014-07-30T00:24:31
# 4          adm1                   USA  2014-07-30T01:39:50
#
#               End time    Time of detection
# 0  2014-08-06T20:35:42  2014-07-30T23:14:12
# 1  2014-08-01T23:49:44  2014-07-30T23:52:33
# 2  2014-08-03T08:53:39  2014-07-30T22:15:47
# ...

# %%
philippine_data = df.loc[df['ISO 3116 country code'] == 'PHL']
philippine_data.info()
philippine_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541 entries, 33 to 17253
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               541 non-null    int64
#  1   location ID            541 non-null    object
#  2   location URL           541 non-null    object
#  3   Location name          541 non-null    object
#  4   Location type          541 non-null    object
#  5   ISO 3116 country code  541 non-null    object
#  6   Start time             541 non-null    object
#  7   End time               541 non-null    object
#  8   Time of detection      541 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 42.3+ KB
#      event_id location ID                     location URL  \
# 33         30   g-7521311  http://www.geonames.org/7521311
# 49         49   g-7521305  http://www.geonames.org/7521305
# 51         51   g-7521301  http://www.geonames.org/7521301
# ...

# %%
philippine_data['Location name'].unique()
# Out:
# array(['National Capital Region', 'Central Luzon', 'Ilocos', 'Calabarzon',
#        'Republic of the Philippines', 'Central Visayas', 'Davao',
#        'Northern Mindanao', 'Mimaropa', 'Soccsksargen',
#        'Autonomous Region in Muslim Mindanao', 'Western Visayas',
#        'Cagayan Valley', 'Bicol', 'Eastern Visayas', 'Caraga',
#        'Cordillera Administrative Region', 'Zamboanga Peninsula'],
#       dtype=object)

# %%
central_visayas_data = df.loc[df['Location name'] == 'Central Visayas']
central_visayas_data.info()
central_visayas_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 286 to 17105
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               73 non-null     int64
#  1   location ID            73 non-null     object
#  2   location URL           73 non-null     object
#  3   Location name          73 non-null     object
#  4   Location type          73 non-null     object
#  5   ISO 3116 country code  73 non-null     object
#  6   Start time             73 non-null     object
#  7   End time               73 non-null     object
#  8   Time of detection      73 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 5.7+ KB
#      event_id location ID                     location URL    Location name  \
# 286       289   g-7521306  http://www.geonames.org/7521306  Central Visayas
# 345       345   g-7521306  http://www.geonames.org/7521306  Central Visayas
# ...

# %%
ncr_data = df.loc[df['Location name'].isin(['National Capital Region', 'Central Luzon', 'Republic of the Philippines'])]
ncr_data.info()
ncr_data.head(56)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156 entries, 33 to 17178
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_id               156 non-null    int64
#  1   location ID            156 non-null    object
#  2   location URL           156 non-null    object
#  3   Location name          156 non-null    object
#  4   Location type          156 non-null    object
#  5   ISO 3116 country code  156 non-null    object
#  6   Start time             156 non-null    object
#  7   End time               156 non-null    object
#  8   Time of detection      156 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 12.2+ KB
#       event_id location ID                     location URL  \
# 33          30   g-7521311  http://www.geonames.org/7521311
# 49          49   g-7521305  http://www.geonames.org/7521305
# 103        101   g-7521311  http://www.geonames.org/7521311
# ...
